# %% [markdown]
# <div align="center">
#
# # SANIYA GUSAIN
# ### 🤖 AI/ML Enthusiast | 📊 Data Analysis Enthusiast
#
# ---
#
# </div>

# %% [markdown]
#  <div style="background: linear-gradient(90deg, #f5a5a2, #f7cbee);
#             padding: 30px;
#             border-radius: 15px;
#             text-align: center;
#             color: white;">
#
# <h1>🎮 Web Scraping & Trend Analysis of Top Steam Games</h1>
#
# <h3>Analyzing Pricing, Reviews & Genre Trends</h3>
#
# <p>Data Analytics Minor Project using Python, BeautifulSoup & Pandas</p>
#
# </div>

# %% [markdown]
# <div style="border-left:8px solid#873260;
#             padding:15px;
#             background:	#f5e4eb;
#             border-radius:10px;
#             color: #000000">
#
# <h2> <b> Objectives: </b></h2>
#
# <ul>
# <li>Introduction</li>
# <li>Overview of web scraping
#     <li>Importance of Data extraction from websites</li>
#     <li>Problem statement</li> </li>
# <li>Project objectives</li>
# <li>Tools and technologies used</li>
# <li>Implementation</li>
# <li>Result and output</li>
# </ul>
#
# </div>

# %% [markdown]
# <div style="
# border-left:8px solid #E8A1A6;
# padding:25px;
# background:#FFFFFF;
# border-radius:15px;
# color:#1E293B;">
#
# <h1 style="
# text-align:center;
# color:#1E293B;
# font-size:42px;
# margin-bottom:10px;">
#
#  <b>   Introduction 🌐</b></h2>
#
# <p style="
# text-align:center;
# color:#E8A1A6;
# font-size:18px;
# margin-top:0;">
# Analyzing Pricing, Reviews & Genre Trends
#
#
# The gaming industry generates vast amounts of data every day, including player reviews, pricing information, genre preferences, and popularity metrics. Steam, one of the world's largest digital game distribution platforms, provides valuable insights into player behavior and market trends.
#
# This project leverages web scraping techniques to collect data from top Steam games and applies data analysis to uncover patterns in pricing, reviews, and genre popularity. By transforming raw web data into meaningful visual insights, the project demonstrates how data-driven approaches can be used to understand trends within the gaming ecosystem.
#
# <table width="100%">
# <tr>
# <td>🕸️ Web Scraping</td>
# <td>📊 Data Analysis</td>
# </tr>
#
# <tr>
# <td>⭐ Review Trends</td>
# <td>🎮 Genre Insights</td>
# </tr>
#
# <tr>
# <td>💰 Pricing Analysis</td>
# <td>📈 Visualization</td>
# </tr>
# </table>
# </p>
# </div>

# %% [markdown]
# <div style="background: #DDB7D9;            padding: 30px;
#             border-radius: 15px;
#
#             color:black;">
#
# <h1 style ='text-align: center'><b>Introduction 🎮 </b></h1>
#
# <h3>
#
# <p>
#
# The gaming industry generates vast amounts of data every day, including player reviews, pricing information, genre preferences, and popularity metrics. Steam, one of the world's largest digital game distribution platforms, provides valuable insights into player behavior and market trends.
#
# This project leverages web scraping techniques to collect data from top Steam games and applies data analysis to uncover patterns in pricing, reviews, and genre popularity. By transforming raw web data into meaningful visual insights, the project demonstrates how data-driven approaches can be used to understand trends within the gaming ecosystem.
#
# **Key Focus Areas**
#
#  * Data Collection through Web Scraping
#  * Data Cleaning and Preprocessing
#  * Trend Analysis of Reviews and Ratings
#  * Genre Popularity Insights
#  * Pricing Pattern Analysis
#  * Data Visualization and Interpretation
# </p>
# </h3>
#
# </div>

# %% [markdown]
# <div style="
# background:#F8F5F7;
# padding:30px;
# border-left:8px solid #E8A1A6;">
#
# <h1 style="
# color:#7C3A4D;
# font-size:42px;
# margin-bottom:10px;">
# 🎯 Problem Statement
# </h1>
#
# <h3 style="
# color:#A16275;
# font-size:24px;
# font-weight:500;">
# Web Scraping & Trend Analysis of Top Steam Games
# </h3>
#
# <hr style="
# border:none;
# height:2px;
# background:#E8A1A6;
# margin:25px 0;">
#
# <p style="
# font-size:20px;
# line-height:1.8;
# color:#B784A7;
# text-align:justify;">
#
# Steam hosts thousands of games with continuously evolving player reviews,
# ratings, pricing information, and genre preferences. Although this data
# contains valuable insights into gaming trends and player behavior, it is
# distributed across multiple web pages and is not readily available in a
# structured format.
#
# </p>
#
# <p style="
# font-size:20px;
# line-height:1.8;
# color:#B784A7;
# text-align:justify;">
#
# Manual collection and analysis of such information is inefficient and
# time-consuming. Therefore, an automated solution is required to extract,
# organize, and analyze Steam game data effectively.
#
# </p>
#
# <p style="
# font-size:20px;
# line-height:1.8;
# color:#B784A7;
# text-align:justify;">
#
# This project addresses this challenge by utilizing web scraping and data
# analysis techniques to identify trends in reviews, pricing, and genre
# popularity, transforming raw web data into meaningful insights.
#
# </p>
#
# </div>

# %% [markdown]
# <div style="background: #FAF5F7;
#             padding: 10px;
#             border-radius: 15px;
#
#             color: white;">
#
# <h3> Project setup </h3>
#
#
#
# </div>

# %% [markdown]
#  <div style="background: #FAF5F7;
#             padding: 10px;
#             border-radius: 15px;
#             color: pink;">
#
#
# <h1> <b>  Project Setup 📊
# </b></h1>
#
#
#
# </div>

# %%
#import requests:
import requests

# %% [markdown]
#  <div style="background: #FAF5F7;
#             padding: 10px;
#             border-radius: 15px;
#             color: pink;">
#
#
# <h1> <b>  Fetch url from Steam( games data collection ) 🌐
# </b></h1>
#
#
#
# </div>

# %%
url = "https://store.steampowered.com/search/?filter=popularnew"
header = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}
response = requests.get(url, headers= header)
response.status_code

# %% [markdown]
#  <div style="background: #FAF5F7;
#             padding: 10px;
#             border-radius: 15px;
#             color: pink;">
#
#
# <h1> <b>  Check Status code
# </b></h1>
#
#
#
# </div>

# %%
response.status_code
response.text

# %% [markdown]
# <div style="background: #FAF5F7;
#             padding: 10px;
#             border-radius: 15px;
#             color: pink;">
#
#
# <h1> <b>  Raw HTML storing inside variable 🌐
# </b></h1>
#
#
#
# </div>

# %%
html_doc = response.text

# %% [markdown]
# <div style="background: #FAF5F7;
#             padding: 10px;
#             border-radius: 15px;
#             color: pink;">
#
#
# <h1> <b>  Importing required libraries 🌐
# </b></h1>
#
#
#
# </div>

# %%
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# <div style="background: #FAF5F7;
#             padding: 10px;
#             border-radius: 15px;
#             color: pink;">
#
#
# <h1> <b> Parse HTML using BeautifulSoup
# </b></h1>
#
#
#
# </div>

# %%
soup = BeautifulSoup(html_doc, "html.parser")
print(soup.prettify())

# %% [markdown]
# <div style="background: #FAF5F7;
#             padding: 10px;
#             border-radius: 15px;
#             color: pink;">
#
#
# <h1> <b> Finding games information container
# </b></h1>
#
#
#
# </div>

# %%
#scraping game name:
games = soup.find_all('a', class_="search_result_row")
games

# %% [markdown]
# <div style="background: #FAF5F7;
#             padding: 10px;
#             border-radius: 15px;
#             color: pink;">
#
#
# <h1> <b>  Extracting games name, price, release date and image url
# </b></h1>
#
#
#
# </div>

# %%
games_data=[]
from urllib.parse import urljoin
image_url =[]
for game in games:
   game_name = game.find('span',class_='title').get_text(strip = True)
   price_element = game.find("div", class_="discount_final_price").get_text(strip = True)
   release_element = game.find("div", class_="search_released").get_text(strip = True)
   
 
   image = game.find('img')
   src = image.get('src')
   
   games_data.append({'game_name': game_name,
      'price': price_element,
      'release': release_element,
      'image_url': urljoin(url,src)
   })
games_data

# %% [markdown]
# <div style="background: #FAF5F7;
#             padding: 10px;
#             border-radius: 15px;
#             color: pink;">
#
#
# <h1> <b>  Converting raw data to DataFrame
# </b></h1>
#
#
#
# </div>

# %%
df = pd.DataFrame(games_data)

# %% [markdown]
# <div style="background: #FAF5F7;
#             padding: 10px;
#             border-radius: 15px;
#             color: pink;">
#
#
# <h1> <b>  Viewing DataFrame/ Extracted data
# </b></h1>
#
#
#
# </div>

# %%
df.head(5)
