# %% [markdown]
# #default package manager for python -> pip. pip install package_name

# %%
"""Data analysis and scientific computing...
pandas-> data manipulation and analysis
numpy-> fast numerical calculations and multidimensional arrays
scipy-> scientific computing(advance mathematics optimisation, integration and stats))
matplotlib-> plotting and visualization
seaborn-> statistical data visualization
plotly-> interactive data visualization,,, bokeh-> interactive visualization for web applications.
sympy-> symbolic mathematics, calculus, algebra and eqn solving.
stats models-> statistical modeling.
scikit-learn-> machine learning
tensorflow-> machine learning and deep learning
keras-> high level neural networks API, runs on top of tensorflow(simplified deep learning development)
pytorch-> machine learning and deep learning
xgboost-> gradient boosting for machine learning(high performance predictive modeling)
lightgbm-> efficientgradient boosting for machine learning"""

# %%
#natural language processing(NLP) libraries
"""nltk-> natural language processing toolkit, text processing, tokenization, stemming and sentiment analysis.
spacy->industrial strengthning library for nlp, fast and efficient for large scale text processing.
transformers-> large language models.
gensim->topic modelling and embeddings for nlp."""
# Out:
# 'nltk-> natural language processing toolkit, text processing, tokenization, stemming and sentiment analysis.\nspacy->industrial strengthning library for nlp, fast and efficient for large scale text processing.\ntransformers-> large language models.\ngensim->topic modelling and embeddings for nlp.'

# %%
#computer visison libraries:
""""opencv-> real time computer vision, image and video processing.
pillow-> image processing and manipulation.
mediapipe-> track face and posture.
"""
# Out:
# '"opencv-> real time computer vision, image and video processing.\npillow-> image processing and manipulation.\nmediapipe-> track face and posture.\n'

# %%
#web development libraries:
"""django->full stack web development framework, follows model view template(MVT) architectural pattern.
flask-> lightweight web framework, micro web framework for small to medium applications.
fastapi-> modern, fast web framework for building APIs with Python 3.7+ based
on standard Python type hints.
jinja-> html templating
"""
# Out:
# 'django->full stack web development framework, follows model view template(MVT) architectural pattern.\nflask-> lightweight web framework, micro web framework for small to medium applications.\nfastapi-> modern, fast web framework for building APIs with Python 3.7+ based\non standard Python type hints.\njinja-> html templating\n'

# %%
#web scraping and automation libraries:
""" requests-> making HTTP requests, handling responses and interacting with web APIs.
beautifulsoup-> parsing HTML and XML documents, extracting data from web pages.
scrapy-> web crawling and scraping framework for large scale web scraping projects.
selenium-> web browser automation, testing and scraping dynamic web content.
playwright-> modern browser automation library."""
# Out:
# ' requests-> making HTTP requests, handling responses and interacting with web APIs.\nbeautifulsoup-> parsing HTML and XML documents, extracting data from web pages.\nscrapy-> web crawling and scraping framework for large scale web scraping projects.\nselenium-> web browser automation, testing and scraping dynamic web content.'

# %%
#database libraries:
"""sqlite3-> built in library for SQLite databases, lightweight and serverless.
pymongo-> MongoDB, a NoSQL database, for working with document-oriented data."""
# Out:
# 'sqlite3-> built in library for SQLite databases, lightweight and serverless.\npymongo-> MongoDB, a NoSQL database, for working with document-oriented data.'

# %%
#GUI Development libraries: not used now:
"""tkinter-> standard library for creating graphical user interfaces, simple and easy to use.
"""
# Out:
# 'tkinter-> standard library for creating graphical user interfaces, simple and easy to use.\n'

# %%
#string:
name="princess"
type(name)
# Out:
# str

# %%
name*3
# Out:
# 'princessprincessprincess'

# %%
name*"3" #error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 name*"3" #error
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
#membership operator: substring in string
"p" in name
# Out:
# True

# %%
name.upper()
# Out:
# 'PRINCESS'

# %%
print(name.split("i" ))
name.split("in",1)#1 is max split
# Out:
# ['pr', 'ncess']
# ['pr', 'cess']

# %%
name.swapcase()
#upper to lower and lower to upper
# Out:
# 'PRINCESS'

# %%
#strip,lstrip and rstrip:
name2="fairy  "
name2.title()
name2.rstrip()
# Out:
# 'fairy'

# %%
s="  i am a good person "
s.strip()
s.title()
s.find("good")
# Out:
# 9

# %%
s_replace=s.replace("good","sagacious")
s_replace
# Out:
# '  i am a sagacious person '

# %%
s_split=s.split()
s_split
# Out:
# ['i', 'am', 'a', 'good', 'person']

# %%
",".join(s_split)
# Out:
# 'i,am,a,good,person'

# %%
" ".join(s_split)
# Out:
# 'i am a good person'

# %%
#escape characters:
print("hello\nworld") #\n is new line
print("hello\tworld") #\t is tab space
print("hello\"world") #\" is double quote
print("hello\'world") #\' is single quote   
print("hello\"world") #\" double quote"
# Out:
# hello
# world
# hello	world
# hello"world
# hello'world
# hello"world

# %%
print('I\'m a data scientist ')
# Out:
# I'm a data scientist

# %%
print("ans">"answ") #based on ascii values.
# Out:
# False

# %%
#to print ascii vales:
print(ord("a"))
print(chr(87))
# Out:
# 97
# W

# %%
num=10
id(num)
# Out:
# 140729583396040

# %%
print(int(34.9))
# Out:
# 34

# %%
v1=0b1010
print(v1)
# Out:
# 10

# %%
v2=0o123
print(v2)
# Out:
# 83

# %%
v3=0x1A
print(v3)
# Out:
# 26

# %%
v5=36
print(bin(v5))
print(oct(v5))
print(hex(v5))
# Out:
# 0b100100
# 0o44
# 0x24

# %%
a=1
b=6
print(a & b)
print(a | b)
print(a^b)
print(b<<1)
print(~a)
# Out:
# 0
# 7
# 7
# 12
# -2

# %%
#cached range: 0 to 256
